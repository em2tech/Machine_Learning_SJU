# %% [markdown]
# <a href="https://colab.research.google.com/github/em2tech/Machine_Learning_SJU/blob/main/HW1/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Part B - Analysis**

# %% [markdown]
# **Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?**

# %% [markdown]
# The key steps are as follows:
# 1. **Initial Setup**
#
#    a.Create a GitHub Account
#
#    b.Create Course Repository in GitHub
#
#    c. Structure Repository with name convention HW1, HW2, etc...
#
# 2. **Develop Assignment in Google Colab**
#
#     a.  Navigate to colab.research.google.com and sign in with Google Account
#
#     b.  Open or create assignment notebook in colab. Code and documents will be written here.
#
#     c. Connect to available resource for computing. If assignment require more resource, you can change runtime to GPU.
#
# 3. **Save and submit completed Assignments in GitHub. Use the following steps:**
#
#     a.In Google Colab navigate to the file menu and locate save a copy to Github option.
#
#     b. Specify  path to correct  subfolder and verify that the file appears.

# %% [markdown]
# **Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?**

# %% [markdown]
# All notebooks in Module 0 ran well, except for the "Pandas" notebook. This was because I had mistakenly skipped importing the pandas and numpy libraries first. Once I added the import statement, the notebook executed without any errors.

# %% [markdown]
# **Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).**

# %% [markdown]
# With a GitHub account, I created my repository using the following steps:
#
# 1. Logged into GitHub with my credentials
# 2. Clicked New at the top right corner
# 3. I am presented with the option to input the name of my repository (Machine_Learning_SJU is what I named it)
# 4. I then create a subdirectory called HW1
# 5. Uploaded all of the notebooks into HW1 which I downloaded from Prof Babak's GitHub Repository  as instructed .
# Below is the image of my file organization:
#
#
# ![GitHub_Repository.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?**

# %% [markdown]
# Without a solid foundation in Python, one will become overwhelmed by debugging of the program which will make it harder to focus on learning the machine learning concepts which is demanding on its own.
